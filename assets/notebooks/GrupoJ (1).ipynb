# %% [markdown]
# **Analisis de Datos del Grupo J
# Universidad Villa Maria 2 y Pampa 2**

# %%
#Realizamos los imports necesarios
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors

# %%
plt.rcParams['figure.dpi'] = 120
plt.rcParams['legend.frameon'] = False
#plt.rcParams['figure.figsize'] = (8,12)
sns.set_style('dark')
colors_green = sns.light_palette("#005200", input='rgb',n_colors=12)[::-1]
colors_red = sns.light_palette("#68081C", input='rgb',n_colors=12)[::-1]
colors_dark = sns.light_palette("#1F1F1F", input='rgb',n_colors=12)[::-1]
sns.palplot(colors_green)
sns.palplot(colors_red)
sns.palplot(colors_dark)

# %%
#Colocamos el nombre de las universidades en dos variables
#Para una futura reutilización del codigo

university1 = 'GrupoJ_Pampa2'
university1_name = 'Universidad de la Pampa'

university2 = 'GrupoJ_Villa_maria2'
university2_name = 'Universidad de Villa Maria'

# %%
df_1 = pd.read_csv(f'datasets/{university1}_process.txt', sep='\t')
df_2 = pd.read_csv(f'datasets/{university2}_process.txt', sep='\t')

# %%
df_1.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'last_name',
#        'gender', 'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'gender',
#        'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_geonames = pd.read_csv('AR_geonames.txt', sep='\t', header=None,on_bad_lines='skip')

# %%
df_geonames.dropna(axis=1, inplace=True)

# %%
df_geonames.columns = ['country','postal_code', 'location', 'region', 'type', 'lat', 'lon', 'type_2']

# %%
df_1geonames_merge = df_geonames.merge(df_1, on='postal_code', how='right')

# %%
df_1geonames_merge
# Out:
#       country  postal_code                     location_x      region type  \
# 0          AR         3232                         CABRED  Corrientes    W
# 1          AR         3232                      GUAVIRAVI  Corrientes    W
# 2          AR         3232                      TAPEBICUA  Corrientes    W
# 3          AR         3232                 PARADA PUCHETA  Corrientes    W
# 4          AR         3232  KILOMETRO 204 (APEADERO FCGU)  Corrientes    W
# ...       ...          ...                            ...         ...  ...
# 12595      AR         5543                COLONIA ALEMANA     Mendoza    M
# 12596      AR         5543                      EL CAÑITO     Mendoza    M
# 12597      AR         5543                   EL RESGUARDO     Mendoza    M
# 12598      AR         5543                  MATHIEU NORTE     Mendoza    M
# 12599      AR         5543              HORNOS DEL MOYANO     Mendoza    M
#
#            lat      lon  type_2                        university  \
# 0     -30.0167 -57.6333     4.0  universidad nacional de la pampa
# 1     -29.3667 -56.8333     4.0  universidad nacional de la pampa
# 2     -29.4833 -56.9833     4.0  universidad nacional de la pampa
# 3     -29.6222 -57.1500     3.0  universidad nacional de la pampa
# 4     -29.6222 -57.1500     3.0  universidad nacional de la pampa
# ...        ...      ...     ...                               ...
# 12595 -32.6833 -68.7100     3.0  universidad nacional de la pampa
# 12596 -32.6833 -68.7100     3.0  universidad nacional de la pampa
# 12597 -32.6833 -68.7100     3.0  universidad nacional de la pampa
# 12598 -32.6833 -68.7100     3.0  universidad nacional de la pampa
# 12599 -32.6833 -68.7100     3.0  universidad nacional de la pampa
#
#                               career inscription_date first_name last_name  \
# 0      licenciatura en musicoterapia       2021-01-22      brett   roberts
# 1      licenciatura en musicoterapia       2021-01-22      brett   roberts
# 2      licenciatura en musicoterapia       2021-01-22      brett   roberts
# 3      licenciatura en musicoterapia       2021-01-22      brett   roberts
# 4      licenciatura en musicoterapia       2021-01-22      brett   roberts
# ...                              ...              ...        ...       ...
# 12595              diseño industrial       2020-09-24    gregory     perry
# 12596              diseño industrial       2020-09-24    gregory     perry
# 12597              diseño industrial       2020-09-24    gregory     perry
# 12598              diseño industrial       2020-09-24    gregory     perry
# 12599              diseño industrial       2020-09-24    gregory     perry
#
#       gender  age location_y                     email
# 0       male   22     cabred  deannalarson@hotmail.com
# 1       male   22     cabred  deannalarson@hotmail.com
# 2       male   22     cabred  deannalarson@hotmail.com
# 3       male   22     cabred  deannalarson@hotmail.com
# 4       male   22     cabred  deannalarson@hotmail.com
# ...      ...  ...        ...                       ...
# 12595   male  100  3 de mayo         derek79@yahoo.com
# 12596   male  100  3 de mayo         derek79@yahoo.com
# 12597   male  100  3 de mayo         derek79@yahoo.com
# 12598   male  100  3 de mayo         derek79@yahoo.com
# 12599   male  100  3 de mayo         derek79@yahoo.com
#
# [12600 rows x 17 columns]

# %%
df_2geonames_merge = df_geonames.merge(df_2, on='postal_code', how='right')

# %%
df_2geonames_merge
# Out:
#       country  postal_code                                    location_x  \
# 0          AR         8134                   LA MASCOTA (PDO. VILLARINO)
# 1          AR         8134                                SALINAS CHICAS
# 2          AR         8134  GRACIARENA (NICOLAS LEVALLE, PDO. VILLARINO)
# 3          AR         8134                                      LA GLEVA
# 4          AR         8134                                COLONIA OCAMPO
# ...       ...          ...                                           ...
# 12768      AR         3453                                   PUNTA IFRAN
# 12769      AR         3453                                      MANCHITA
# 12770      AR         3453                                    PARANACITO
# 12771      AR         3453                                         IFRAN
# 12772      AR         3453                               ISABEL VICTORIA
#
#              region type      lat      lon  type_2  \
# 0      Buenos Aires    B -38.8444 -63.1222     3.0
# 1      Buenos Aires    B -38.8444 -63.1222     3.0
# 2      Buenos Aires    B -38.8444 -63.1222     3.0
# 3      Buenos Aires    B -38.8444 -63.1222     3.0
# 4      Buenos Aires    B -38.8444 -63.1222     3.0
# ...             ...  ...      ...      ...     ...
# 12768    Corrientes    W -29.0833 -59.0250     3.0
# 12769    Corrientes    W -29.0833 -59.0250     3.0
# 12770    Corrientes    W -29.0833 -59.0250     3.0
# 12771    Corrientes    W -29.0667 -58.9667     4.0
# 12772    Corrientes    W -29.1000 -59.0833     4.0
#
#                                 university                     career  \
# 0      universidad nacional de villa maría  diseño de imagen y sonido
# 1      universidad nacional de villa maría  diseño de imagen y sonido
# 2      universidad nacional de villa maría  diseño de imagen y sonido
# 3      universidad nacional de villa maría  diseño de imagen y sonido
# 4      universidad nacional de villa maría  diseño de imagen y sonido
# ...                                    ...                        ...
# 12768  universidad nacional de villa maría     ingeniería electrónica
# 12769  universidad nacional de villa maría     ingeniería electrónica
# 12770  universidad nacional de villa maría     ingeniería electrónica
# 12771  universidad nacional de villa maría     ingeniería electrónica
# 12772  universidad nacional de villa maría     ingeniería electrónica
#
#       inscription_date        first_name  gender  age location_y  \
# 0            17-Nov-19       megan ayala  female   21   ARGERICH
# 1            17-Nov-19       megan ayala  female   21   ARGERICH
# 2            17-Nov-19       megan ayala  female   21   ARGERICH
# 3            17-Nov-19       megan ayala  female   21   ARGERICH
# 4            17-Nov-19       megan ayala  female   21   ARGERICH
# ...                ...               ...     ...  ...        ...
# 12768        24-Dec-19  jennifer walters  female   21      IFRAN
# 12769        24-Dec-19  jennifer walters  female   21      IFRAN
# 12770        24-Dec-19  jennifer walters  female   21      IFRAN
# 12771        24-Dec-19  jennifer walters  female   21      IFRAN
# 12772        24-Dec-19  jennifer walters  female   21      IFRAN
#
#                         email
# 0         lrivera@hotmail.com
# 1         lrivera@hotmail.com
# 2         lrivera@hotmail.com
# 3         lrivera@hotmail.com
# 4         lrivera@hotmail.com
# ...                       ...
# 12768  michaelscott@yahoo.com
# 12769  michaelscott@yahoo.com
# 12770  michaelscott@yahoo.com
# 12771  michaelscott@yahoo.com
# 12772  michaelscott@yahoo.com
#
# [12773 rows x 16 columns]

# %% [markdown]
# TOP 10 de carreras con más alumnos y con menos alumnos

# %%
df_aux = df_1.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_1.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.head(10), x='university', y='career', palette=colors_green, ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_green[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con más personas - {university1_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_aux = df_1.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_1.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.tail(10), x='university', y='career', palette=colors_red[10::-1], ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_red[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con menos personas - {university1_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_aux = df_2.groupby('career').count().reset_index().sort_values('university', ascending=False)
palette = sns.diverging_palette(120,12,s=55,l=70,n=33,center='dark')
plt.figure(figsize=(10, 8))
sns.barplot(data=df_aux, x='university', y='career', palette=palette)

plt.title(f'Personas por carrera - {university2_name}')
plt.xlabel('Cantidad de personas')
plt.ylabel('Carrera')

plt.show()

# %%
df_aux = df_2.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_2.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.tail(10), x='university', y='career', palette=colors_red[10::-1], ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_red[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con menos personas - {university2_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_1.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'last_name',
#        'gender', 'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_1.shape
# Out:
# (1304, 10)

# %%
df_1.head()
# Out:
#                          university                         career  \
# 0  universidad nacional de la pampa  licenciatura en musicoterapia
# 1  universidad nacional de la pampa                       farmacia
# 2  universidad nacional de la pampa     licenciatura en sociología
# 3  universidad nacional de la pampa      ingeniería en informática
# 4  universidad nacional de la pampa                       actuario
#
#   inscription_date first_name   last_name  gender  age  postal_code  \
# 0       2021-01-22      brett     roberts    male   22         3232
# 1       2020-12-29       chad  richardson    male   45         3185
# 2       2020-09-03  cassandra    odonnell  female   67         7245
# 3       2020-10-23        ann     schmidt  female   78         2255
# 4       2020-09-28  gabrielle     johnson  female   25         3071
#
#            location                        email
# 0            cabred     deannalarson@hotmail.com
# 1  colonia la marta  jacksonmichelle@hotmail.com
# 2      campo sabate      jamesthompson@gmail.com
# 3   campo rodriguez          michael73@gmail.com
# 4     aguara grande            ipage@hotmail.com

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1304 entries, 0 to 1303
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   university        1304 non-null   object
#  1   career            1304 non-null   object
#  2   inscription_date  1304 non-null   object
#  3   first_name        1304 non-null   object
#  4   last_name         1304 non-null   object
#  5   gender            1304 non-null   object
#  6   age               1304 non-null   int64
#  7   postal_code       1304 non-null   int64
#  8   location          1304 non-null   object
#  9   email             1304 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 102.0+ KB

# %%
df_2.describe()
# Out:
#                age  postal_code
# count  1286.000000  1286.000000
# mean     24.538880  4956.298600
# std       7.440114  2108.977969
# min      19.000000  1602.000000
# 25%      21.000000  3048.000000
# 50%      21.000000  5318.000000
# 75%      22.000000  6559.000000
# max      50.000000  9225.000000

# %%
sns.violinplot(data=df_1,y='age', x='gender', palette=[colors_red[4], colors_green[4]])

# %%
sns.violinplot(data=df_2,y='age', x='gender', palette=[colors_red[4], colors_green[4]])

# %% [markdown]
# **Top 10 localidades por alumnos**

# %%
df_1.location.value_counts().head(10)
# Out:
# 9 de julio       6
# arroyo grande    6
# la lucila        5
# agua colorada    5
# algarrobo        5
# aguada           4
# dos hermanos     4
# barro negro      4
# el brete         4
# centinela        4
# Name: location, dtype: int64

# %%
df_2.location.value_counts().head(10)
# Out:
# ALGARROBO      12
# ALGARROBAL     11
# ANGOSTURA      11
# CASEROS         8
# AGUADITA        8
# BERABEVU        8
# ACONQUIJA       7
# CENTENARIO      7
# CRISTOLIA       7
# BARRIALITOS     6
# Name: location, dtype: int64

# %% [markdown]
# **Distribucion de alumnos por edad y género**

# %%
sns.histplot(data=df_1,x='age', hue='gender', kde=True,fill=True,multiple='dodge', shrink=.5,stat='density', palette=[colors_red[4], colors_green[4]])

# %%
sns.histplot(data=df_2,x='age', hue='gender', kde=True,fill=True,multiple='dodge', shrink=.5,stat='density', palette=[colors_red[4], colors_green[4]])

# %%
df_1.inscription_date = pd.to_datetime(df_1.inscription_date)
df_2.inscription_date = pd.to_datetime(df_2.inscription_date)

# %% [markdown]
# Segregación por tipo de carrera

# %%
def clasificador(x):
    
    clasificador ={
    'exactas_nat':['agronomía','licenciatura en ciencias biológicas','licenciatura en ciencias ambientales','licenciatura en ciencias biológicas', 'licenciatura en ciencias geológicas', 
    'técnico para bioterios', 'ingeniería electrónica', 'ingeniería en informática','ingeniería mecánica','licenciatura en ciencias de la computación'],
    'ciencias_salud':['ciencias veterinarias','farmacia','licenciatura en kinesiología y fisiatría','licenciatura en producción de bioimagenes','medicina','licenciatura en gestión de agroalimentos', 'licenciatura en ciencia y tecnología de alimentos','bioquímica'],
    'diseño_art':['diseño industrial', 'diseño de imagen y sonido', 'licenciatura en artes', 'licenciatura en musicoterapia', ],
    'empresarial':['actuario', 'contador público','licenciatura en administración'],
    'sociales':['licenciatura en ciencias antropológicas','licenciatura en ciencias de la educación','licenciatura en psicología', 'licenciatura en relaciones del trabajo','licenciatura en sociología','licenciatura en terapia ocupacional']
}
    if x in clasificador['exactas_nat']:
        return "Exactas y Naturales"
    elif x in clasificador['diseño_art']:
        return "Artes y Diseño"
    elif x in clasificador['empresarial']:
        return "Ciencias Empresariales"
    elif x in clasificador['ciencias_salud']:
        return "Salud"
    else:
        return "Sociales"
df_1['tipo_career'] = df_1.career.apply(clasificador)

# %% [markdown]
# Proporción de alumnos por tipo de carrera y género

# %%
fig,ax = plt.subplots(figsize=(10,5))
g = sns.countplot(data=df_1,
                    x='tipo_career',
                    hue='gender',
                    palette=[colors_red[5],
                    colors_green[5]],
                    ax=ax)

g.set_title(f'Tipo de Carrera por Género - {university1_name}',{'fontsize':15})
g.set_ylabel('Cantidad de alumnos',{'fontsize':12,'color':colors_dark[3]})
g.set_xlabel('Tipo de carrera',{'fontsize':12,'color':colors_dark[3]})
g.set_xticklabels(labels=g.get_xticklabels())
ax.legend(labels=['Mujer','Varon'])

# %%
fig,ax=plt.subplots(figsize=(15,4))
df_aux = df_1geonames_merge.pivot_table(
    index=['region'],
    columns='gender',
    values=['first_name'],
    aggfunc={'region':'count'}
)
df_aux.plot(kind='bar',color=(colors_red[5],colors_green[5]),ax=ax)
ax.set_title(f'Alumnos por región y por género - {university1_name}',{'fontsize':15})
ax.set_ylabel('Cantidad de alumnos',{'color':colors_dark[3]})
ax.tick_params(axis='x', colors=colors_dark[3])
ax.set_xlabel('')
ax.legend(labels=['Mujer','Varon'])
fig.show()

# %%
def clasificador(x):
    
    clasificador ={
    'exactas_nat':['agronomía','licenciatura en ciencias biológicas','licenciatura en ciencias ambientales','licenciatura en ciencias biológicas', 'licenciatura en ciencias geológicas', 
    'técnico para bioterios', 'ingeniería electrónica', 'ingeniería en informática','ingeniería mecánica','licenciatura en ciencias de la computación'],
    'ciencias_salud':['ciencias veterinarias','farmacia','licenciatura en kinesiología y fisiatría','licenciatura en producción de bioimagenes','medicina','licenciatura en gestión de agroalimentos', 'licenciatura en ciencia y tecnología de alimentos','bioquímica'],
    'diseño_art':['diseño industrial', 'diseño de imagen y sonido', 'licenciatura en artes', 'licenciatura en musicoterapia', ],
    'empresarial':['actuario', 'contador público','licenciatura en administración'],
    'sociales':['licenciatura en ciencias antropológicas','licenciatura en ciencias de la educación','licenciatura en psicología', 'licenciatura en relaciones del trabajo','licenciatura en sociología','licenciatura en terapia ocupacional']
}
    if x in clasificador['exactas_nat']:
        return "Exactas y Naturales"
    elif x in clasificador['diseño_art']:
        return "Artes y Diseño"
    elif x in clasificador['empresarial']:
        return "Ciencias Empresariales"
    elif x in clasificador['ciencias_salud']:
        return "Salud"
    else:
        return "Sociales"
df_2['tipo_career'] = df_2.career.apply(clasificador)

# %%
fig,ax = plt.subplots(figsize=(10,5))
g = sns.countplot(data=df_2,
                    x='tipo_career',
                    hue='gender',
                    palette=[colors_red[5],
                    colors_green[5]],
                    ax=ax)

g.set_title(f'Tipo de Carrera por Género - {university2_name}',{'fontsize':15})
g.set_ylabel('Cantidad de alumnos',{'fontsize':12,'color':colors_dark[3]})
g.set_xlabel('Tipo de carrera',{'fontsize':12,'color':colors_dark[3]})
g.set_xticklabels(labels=g.get_xticklabels())
ax.legend(labels=['Mujer','Varon'])

# %%
fig,ax=plt.subplots(figsize=(15,4))
df_aux = df_2geonames_merge.pivot_table(
    index=['region'],
    columns='gender',
    values=['first_name'],
    aggfunc={'region':'count'}
)
df_aux.plot(kind='bar',color=(colors_red[5],colors_green[5]),ax=ax)
ax.set_title(f'Alumnos por región y por género - {university2_name}',{'fontsize':15})
ax.set_ylabel('Cantidad de alumnos',{'color':colors_dark[3]})
ax.tick_params(axis='x', colors=colors_dark[3])
ax.set_xlabel('')
ax.legend(labels=['Mujer','Varon'])
fig.show()

# %%
career = 'ingeniería en informática'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()

# %%
career = 'bioquímica'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()

# %%
career = 'medicina'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()
