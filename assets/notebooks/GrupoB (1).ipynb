# %% [markdown]
# Analisis de Datos del Grupo B
# Universidad de Comahue y Universidad del Salvador

# %%
#Realizamos los imports necesarios
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors

# %%
plt.rcParams['figure.dpi'] = 120
plt.rcParams['legend.frameon'] = False
#plt.rcParams['figure.figsize'] = (8,12)
sns.set_style('dark')
colors_green = sns.light_palette("#005200", input='rgb',n_colors=12)[::-1]
colors_red = sns.light_palette("#68081C", input='rgb',n_colors=12)[::-1]
colors_dark = sns.light_palette("#1F1F1F", input='rgb',n_colors=12)[::-1]
sns.palplot(colors_green)
sns.palplot(colors_red)
sns.palplot(colors_dark)

# %%
#Colocamos el nombre de las universidades en dos variables
#Para una futura reutilización del codigo

university1 = 'GrupoB_comahue_universidad'
university1_name = 'Universidad de Comahue'

university2 = 'GrupoB_salvador_universidad'
university2_name = 'Universidad del Salvador'

# %%
df_1 = pd.read_csv(f'datasets/{university1}_process.txt', sep='\t')
df_2 = pd.read_csv(f'datasets/{university2}_process.txt', sep='\t')

# %%
df_1.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'gender',
#        'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'gender',
#        'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_geonames = pd.read_csv('AR_geonames.txt', sep='\t', header=None,on_bad_lines='skip')

# %%
df_geonames.dropna(axis=1, inplace=True)

# %%
df_geonames.columns = ['country','postal_code', 'location', 'region', 'type', 'lat', 'lon', 'type_2']

# %%
df_1geonames_merge = df_geonames.merge(df_1, on='postal_code', how='right')

# %%
df_1geonames_merge
# Out:
#       country  postal_code                              location_x  \
# 0          AR         8129                             FELIPE SOLA
# 1          AR         8129                    DIECISIETE DE AGOSTO
# 2          AR         8129                               GLORIALDO
# 3          AR         3328                               LA OTILIA
# 4          AR         3328                                  OTILIA
# ...       ...          ...                                     ...
# 10856      AR         6307  LA ESPERANZA (MACACHIN, DPTO. ATREUCO)
# 10857      AR         6307                              LA ORACION
# 10858      AR         6307                              LA ANTONIA
# 10859      AR         6307                                 HIDALGO
# 10860      AR         6307                                MACACHIN
#
#              region type      lat      lon  type_2  \
# 0      Buenos Aires    B -38.0167 -62.8333     4.0
# 1      Buenos Aires    B -37.9167 -62.9333     4.0
# 2      Buenos Aires    B -37.9667 -62.8833     3.0
# 3          Misiones    N -27.0192 -55.2609     3.0
# 4          Misiones    N -27.0192 -55.2609     3.0
# ...             ...  ...      ...      ...     ...
# 10856      La Pampa    L -37.1583 -63.5917     3.0
# 10857      La Pampa    L -37.1583 -63.5917     3.0
# 10858      La Pampa    L -37.1583 -63.5917     3.0
# 10859      La Pampa    L -37.1667 -63.5333     4.0
# 10860      La Pampa    L -37.1500 -63.6500     4.0
#
#                        university            career inscription_date  \
# 0      univ. nacional del comahue  contador público       2020-10-31
# 1      univ. nacional del comahue  contador público       2020-10-31
# 2      univ. nacional del comahue  contador público       2020-10-31
# 3      univ. nacional del comahue         agronomía       2021-01-31
# 4      univ. nacional del comahue         agronomía       2021-01-31
# ...                           ...               ...              ...
# 10856  univ. nacional del comahue      arquitectura       2020-12-04
# 10857  univ. nacional del comahue      arquitectura       2020-12-04
# 10858  univ. nacional del comahue      arquitectura       2020-12-04
# 10859  univ. nacional del comahue      arquitectura       2020-12-04
# 10860  univ. nacional del comahue      arquitectura       2020-12-04
#
#                first_name  gender  age          location_y  \
# 0             amanda hill  female   32        17 de agosto
# 1             amanda hill  female   32        17 de agosto
# 2             amanda hill  female   32        17 de agosto
# 3              ryan davis    male   87    colonia japonesa
# 4              ryan davis    male   87    colonia japonesa
# ...                   ...     ...  ...                 ...
# 10856  stephen harrington    male   89  colonia la oracion
# 10857  stephen harrington    male   89  colonia la oracion
# 10858  stephen harrington    male   89  colonia la oracion
# 10859  stephen harrington    male   89  colonia la oracion
# 10860  stephen harrington    male   89  colonia la oracion
#
#                           email
# 0           tyler57@hotmail.com
# 1           tyler57@hotmail.com
# 2           tyler57@hotmail.com
# 3      patriciazamora@gmail.com
# 4      patriciazamora@gmail.com
# ...                         ...
# 10856    francesmiles@gmail.com
# 10857    francesmiles@gmail.com
# 10858    francesmiles@gmail.com
# 10859    francesmiles@gmail.com
# 10860    francesmiles@gmail.com
#
# [10861 rows x 16 columns]

# %%
df_2geonames_merge = df_geonames.merge(df_2, on='postal_code', how='right')

# %%
df_2geonames_merge
# Out:
#       country  postal_code              location_x        region type  \
# 0          AR         2747          CORONEL ISLEÑO  Buenos Aires    B
# 1          AR         2747             INES INDART  Buenos Aires    B
# 2          AR         6535  SANTA MARIA DE BELLOCQ  Buenos Aires    B
# 3          AR         6535                  CADRET  Buenos Aires    B
# 4          AR         6535     COLONIA SANTA MARIA  Buenos Aires    B
# ...       ...          ...                     ...           ...  ...
# 23951      AR         6003             LA TRINIDAD  Buenos Aires    B
# 23952      AR         6439              LA MANUELA  Buenos Aires    B
# 23953      AR         6439                    LURO  Buenos Aires    B
# 23954      AR         6439               BONIFACIO  Buenos Aires    B
# 23955      AR         6439           LAGUNA ALSINA  Buenos Aires    B
#
#            lat      lon  type_2                university  \
# 0     -34.4167 -60.4000     4.0  universidad del salvador
# 1     -34.4000 -60.5500     4.0  universidad del salvador
# 2     -35.8083 -61.3667     3.0  universidad del salvador
# 3     -35.7833 -61.3333     4.0  universidad del salvador
# 4     -35.8083 -61.3667     3.0  universidad del salvador
# ...        ...      ...     ...                       ...
# 23951 -34.1000 -61.1333     4.0  universidad del salvador
# 23952 -36.7333 -62.0500     4.0  universidad del salvador
# 23953 -36.6333 -62.1333     4.0  universidad del salvador
# 23954 -36.8167 -62.2167     4.0  universidad del salvador
# 23955 -36.8167 -62.2167     4.0  universidad del salvador
#
#                                         career inscription_date  \
# 0              licenciatura en administración         17-Sep-20
# 1              licenciatura en administración         17-Sep-20
# 2      licenciatura en relaciones del trabajo         01-Oct-20
# 3      licenciatura en relaciones del trabajo         01-Oct-20
# 4      licenciatura en relaciones del trabajo         01-Oct-20
# ...                                        ...              ...
# 23951        licenciatura en ciencia política         11-Sep-20
# 23952                               bioquímica        07-Nov-20
# 23953                               bioquímica        07-Nov-20
# 23954                               bioquímica        07-Nov-20
# 23955                               bioquímica        07-Nov-20
#
#                 first_name gender  age       location_y  \
# 0           james_gonzalez   male   21  coronel isleños
# 1           james_gonzalez   male   21  coronel isleños
# 2      christopher_russell   male   21          bellocq
# 3      christopher_russell   male   21          bellocq
# 4      christopher_russell   male   21          bellocq
# ...                    ...    ...  ...              ...
# 23951        bryce_navarro   male   21        ascencion
# 23952       ricardo_morris   male   21        bonifacio
# 23953       ricardo_morris   male   21        bonifacio
# 23954       ricardo_morris   male   21        bonifacio
# 23955       ricardo_morris   male   21        bonifacio
#
#                            email
# 0      josephjackson@hotmail.com
# 1      josephjackson@hotmail.com
# 2      pattersonjeremy@gmail.com
# 3      pattersonjeremy@gmail.com
# 4      pattersonjeremy@gmail.com
# ...                          ...
# 23951    brownsydney@hotmail.com
# 23952        qdudley@hotmail.com
# 23953        qdudley@hotmail.com
# 23954        qdudley@hotmail.com
# 23955        qdudley@hotmail.com
#
# [23956 rows x 16 columns]

# %% [markdown]
# **TOP 10 de carreras con más alumnos y con menos alumnos**

# %%
df_aux = df_1.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_1.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.head(10), x='university', y='career', palette=colors_green, ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_green[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con más personas - {university1_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_aux = df_1.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_1.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.tail(10), x='university', y='career', palette=colors_red[10::-1], ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_red[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con menos personas - {university1_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_aux = df_2.groupby('career').count().reset_index().sort_values('university', ascending=False)
palette = sns.diverging_palette(120,12,s=55,l=70,n=33,center='dark')
plt.figure(figsize=(10, 8))
sns.barplot(data=df_aux, x='university', y='career', palette=palette)

plt.title(f'Personas por carrera - {university2_name}')
plt.xlabel('Cantidad de personas')
plt.ylabel('Carrera')

plt.show()

# %%
df_aux = df_2.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_2.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.tail(10), x='university', y='career', palette=colors_red[10::-1], ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_red[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con menos personas - {university2_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_1.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'gender',
#        'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_1.shape
# Out:
# (1119, 9)

# %%
df_1.head()
# Out:
#                    university                                    career  \
# 0  univ. nacional del comahue                          contador público
# 1  univ. nacional del comahue                                 agronomía
# 2  univ. nacional del comahue                         diseño industrial
# 3  univ. nacional del comahue       licenciatura en ciencias geológicas
# 4  univ. nacional del comahue  licenciatura en gestión de agroalimentos
#
#   inscription_date        first_name  gender  age  postal_code  \
# 0       2020-10-31       amanda hill  female   32         8129
# 1       2021-01-31        ryan davis    male   87         3328
# 2       2020-12-03     sandra burton  female   52         4500
# 3       2020-11-24  rebekah gonzales  female   43         7609
# 4       2020-10-23      laura gibson  female   84         3087
#
#               location                     email
# 0         17 de agosto       tyler57@hotmail.com
# 1     colonia japonesa  patriciazamora@gmail.com
# 2   alto del saladillo     kleinlauren@gmail.com
# 3  balneario la caleta          mterry@yahoo.com
# 4              felicia  carmenmckinney@yahoo.com

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   university        1119 non-null   object
#  1   career            1119 non-null   object
#  2   inscription_date  1119 non-null   object
#  3   first_name        1119 non-null   object
#  4   gender            1119 non-null   object
#  5   age               1119 non-null   int64
#  6   postal_code       1119 non-null   int64
#  7   location          1119 non-null   object
#  8   email             1119 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 78.8+ KB

# %%
df_2.describe()
# Out:
#                age  postal_code
# count  2193.000000  2193.000000
# mean     24.384405  4828.636115
# std       7.350547  2125.643950
# min      19.000000  1602.000000
# 25%      21.000000  3105.000000
# 50%      21.000000  4701.000000
# 75%      21.000000  6441.000000
# max      50.000000  9421.000000

# %%
sns.violinplot(data=df_1,y='age', x='gender', palette=[colors_red[4], colors_green[4]])

# %%
sns.violinplot(data=df_2,y='age', x='gender', palette=[colors_red[4], colors_green[4]])

# %% [markdown]
# **Top 10 localidades por alumnos**

# %%
df_1.location.value_counts().head(10)
# Out:
# 9 de julio               7
# 25 de mayo               7
# agua colorada            6
# arroyo burgos            5
# colonia lia y allende    5
# gobernador moyano        5
# baldes de pacheco        4
# general galarza          4
# colonia bella vista      4
# dique toma               4
# Name: location, dtype: int64

# %%
df_2.location.value_counts().head(10)
# Out:
# agua colorada    50
# 25 de mayo       45
# 9 de julio       36
# algarrobo        24
# alpachiri        20
# agua blanca      15
# alegria          14
# buena vista      12
# alto verde       12
# caraguatay       12
# Name: location, dtype: int64

# %% [markdown]
# **Distribucion de alumnos por edad y género**

# %%
sns.histplot(data=df_1,x='age', hue='gender', kde=True,fill=True,multiple='dodge', shrink=.5,stat='density', palette=[colors_red[4], colors_green[4]])

# %%
sns.histplot(data=df_2,x='age', hue='gender', kde=True,fill=True,multiple='dodge', shrink=.5,stat='density', palette=[colors_red[4], colors_green[4]])

# %%
df_1.inscription_date = pd.to_datetime(df_1.inscription_date)
df_2.inscription_date = pd.to_datetime(df_2.inscription_date)

# %% [markdown]
# Segregación por tipo de carrera

# %%
def clasificador(x):
    
    clasificador ={
    'exactas_nat':['agronomía','licenciatura en ciencias biológicas','licenciatura en ciencias ambientales','licenciatura en ciencias biológicas', 'licenciatura en ciencias geológicas', 
    'técnico para bioterios', 'ingeniería electrónica', 'ingeniería en informática','ingeniería mecánica','licenciatura en ciencias de la computación'],
    'ciencias_salud':['ciencias veterinarias','farmacia','licenciatura en kinesiología y fisiatría','licenciatura en producción de bioimagenes','medicina','licenciatura en gestión de agroalimentos', 'licenciatura en ciencia y tecnología de alimentos','bioquímica'],
    'diseño_art':['diseño industrial', 'diseño de imagen y sonido', 'licenciatura en artes', 'licenciatura en musicoterapia', ],
    'empresarial':['actuario', 'contador público','licenciatura en administración'],
    'sociales':['licenciatura en ciencias antropológicas','licenciatura en ciencias de la educación','licenciatura en psicología', 'licenciatura en relaciones del trabajo','licenciatura en sociología','licenciatura en terapia ocupacional']
}
    if x in clasificador['exactas_nat']:
        return "Exactas y Naturales"
    elif x in clasificador['diseño_art']:
        return "Artes y Diseño"
    elif x in clasificador['empresarial']:
        return "Ciencias Empresariales"
    elif x in clasificador['ciencias_salud']:
        return "Salud"
    else:
        return "Sociales"
df_1['tipo_career'] = df_1.career.apply(clasificador)

# %% [markdown]
# Proporción de alumnos por tipo de carrera y género

# %%
fig,ax = plt.subplots(figsize=(10,5))
g = sns.countplot(data=df_1,
                    x='tipo_career',
                    hue='gender',
                    palette=[colors_red[5],
                    colors_green[5]],
                    ax=ax)

g.set_title(f'Tipo de Carrera por Género - {university1_name}',{'fontsize':15})
g.set_ylabel('Cantidad de alumnos',{'fontsize':12,'color':colors_dark[3]})
g.set_xlabel('Tipo de carrera',{'fontsize':12,'color':colors_dark[3]})
g.set_xticklabels(labels=g.get_xticklabels())
ax.legend(labels=['Mujer','Varon'])

# %%
fig,ax=plt.subplots(figsize=(15,4))
df_aux = df_1geonames_merge.pivot_table(
    index=['region'],
    columns='gender',
    values=['first_name'],
    aggfunc={'region':'count'}
)
df_aux.plot(kind='bar',color=(colors_red[5],colors_green[5]),ax=ax)
ax.set_title(f'Alumnos por región y por género - {university1_name}',{'fontsize':15})
ax.set_ylabel('Cantidad de alumnos',{'color':colors_dark[3]})
ax.tick_params(axis='x', colors=colors_dark[3])
ax.set_xlabel('')
ax.legend(labels=['Mujer','Varon'])
fig.show()

# %%
def clasificador(x):
    
    clasificador ={
    'exactas_nat':['agronomía','licenciatura en ciencias biológicas','licenciatura en ciencias ambientales','licenciatura en ciencias biológicas', 'licenciatura en ciencias geológicas', 
    'técnico para bioterios', 'ingeniería electrónica', 'ingeniería en informática','ingeniería mecánica','licenciatura en ciencias de la computación'],
    'ciencias_salud':['ciencias veterinarias','farmacia','licenciatura en kinesiología y fisiatría','licenciatura en producción de bioimagenes','medicina','licenciatura en gestión de agroalimentos', 'licenciatura en ciencia y tecnología de alimentos','bioquímica'],
    'diseño_art':['diseño industrial', 'diseño de imagen y sonido', 'licenciatura en artes', 'licenciatura en musicoterapia', ],
    'empresarial':['actuario', 'contador público','licenciatura en administración'],
    'sociales':['licenciatura en ciencias antropológicas','licenciatura en ciencias de la educación','licenciatura en psicología', 'licenciatura en relaciones del trabajo','licenciatura en sociología','licenciatura en terapia ocupacional']
}
    if x in clasificador['exactas_nat']:
        return "Exactas y Naturales"
    elif x in clasificador['diseño_art']:
        return "Artes y Diseño"
    elif x in clasificador['empresarial']:
        return "Ciencias Empresariales"
    elif x in clasificador['ciencias_salud']:
        return "Salud"
    else:
        return "Sociales"
df_2['tipo_career'] = df_2.career.apply(clasificador)

# %%
fig,ax = plt.subplots(figsize=(10,5))
g = sns.countplot(data=df_2,
                    x='tipo_career',
                    hue='gender',
                    palette=[colors_red[5],
                    colors_green[5]],
                    ax=ax)

g.set_title(f'Tipo de Carrera por Género - {university2_name}',{'fontsize':15})
g.set_ylabel('Cantidad de alumnos',{'fontsize':12,'color':colors_dark[3]})
g.set_xlabel('Tipo de carrera',{'fontsize':12,'color':colors_dark[3]})
g.set_xticklabels(labels=g.get_xticklabels())
ax.legend(labels=['Mujer','Varon'])

# %%
fig,ax=plt.subplots(figsize=(15,4))
df_aux = df_2geonames_merge.pivot_table(
    index=['region'],
    columns='gender',
    values=['first_name'],
    aggfunc={'region':'count'}
)
df_aux.plot(kind='bar',color=(colors_red[5],colors_green[5]),ax=ax)
ax.set_title(f'Alumnos por región y por género - {university2_name}',{'fontsize':15})
ax.set_ylabel('Cantidad de alumnos',{'color':colors_dark[3]})
ax.tick_params(axis='x', colors=colors_dark[3])
ax.set_xlabel('')
ax.legend(labels=['Mujer','Varon'])
fig.show()

# %%
career = 'ingeniería en informática'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()

# %%
career = 'bioquímica'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()

# %%
career = 'medicina'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()
