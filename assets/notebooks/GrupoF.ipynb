# %% [markdown]
# **Analisis de Datos del Grupo E Universidades de Moron y Rio Cuarto**

# %%
#Realizamos los imports necesarios
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors

# %%
plt.rcParams['figure.dpi'] = 120
plt.rcParams['legend.frameon'] = False
#plt.rcParams['figure.figsize'] = (8,12)
sns.set_style('dark')
colors_green = sns.light_palette("#005200", input='rgb',n_colors=12)[::-1]
colors_red = sns.light_palette("#68081C", input='rgb',n_colors=12)[::-1]
colors_dark = sns.light_palette("#1F1F1F", input='rgb',n_colors=12)[::-1]
sns.palplot(colors_green)
sns.palplot(colors_red)
sns.palplot(colors_dark)

# %%
#Colocamos el nombre de las universidades en dos variables
#Para una futura reutilización del codigo

university1 = 'GrupoF_moron_universidad'
university1_name = 'Universidad de Moron'

university2 = 'GrupoF_rio_cuarto_universidad'
university2_name = 'Universidad de Rio Cuarto'

# %%
df_1 = pd.read_csv(f'datasets/{university1}_process.txt', sep='\t')
df_2 = pd.read_csv(f'datasets/{university2}_process.txt', sep='\t')

# %%
df_1.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'last_name',
#        'gender', 'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_2.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'last_name',
#        'gender', 'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_geonames = pd.read_csv('AR_geonames.txt', sep='\t', header=None,on_bad_lines='skip')

# %%
df_geonames.dropna(axis=1, inplace=True)

# %%
df_geonames.columns = ['country','postal_code', 'location', 'region', 'type', 'lat', 'lon', 'type_2']

# %%
df_1geonames_merge = df_geonames.merge(df_1, on='postal_code', how='right')

# %%
df_1geonames_merge
# Out:
#       country  postal_code                     location_x        region type  \
# 0          AR         3083                   GRUTLY NORTE      Santa Fe    S
# 1          AR         3083                         GRUTLY      Santa Fe    S
# 2          AR         5471                   VILLA CHEPES      La Rioja    F
# 3          AR         5471                       EL BALDE      La Rioja    F
# 4          AR         5471                     LA CALLANA      La Rioja    F
# ...       ...          ...                            ...           ...  ...
# 12923      AR         6661               LUCAS MONTEVERDE  Buenos Aires    B
# 12924      AR         6661                  BLAS DURAÑONA  Buenos Aires    B
# 12925      AR         6661  SAN ENRIQUE (PDO. 25 DE MAYO)  Buenos Aires    B
# 12926      AR         6661                      PUEBLITOS  Buenos Aires    B
# 12927      AR         6661                      MAMAGUITA  Buenos Aires    B
#
#            lat      lon  type_2            university  \
# 0     -31.2167 -61.1000     4.0  universidad de morón
# 1     -31.2667 -61.0500     4.0  universidad de morón
# 2     -31.2667 -66.6000     4.0  universidad de morón
# 3     -31.4485 -66.6061     3.0  universidad de morón
# 4     -31.4485 -66.6061     3.0  universidad de morón
# ...        ...      ...     ...                   ...
# 12923 -35.5000 -59.9833     4.0  universidad de morón
# 12924 -35.4833 -60.1500     4.0  universidad de morón
# 12925 -35.5750 -60.1083     3.0  universidad de morón
# 12926 -35.6333 -60.0833     4.0  universidad de morón
# 12927 -35.6833 -60.2167     4.0  universidad de morón
#
#                                career inscription_date first_name last_name  \
# 0               licenciatura en artes       2020-10-28     sandra   simpson
# 1               licenciatura en artes       2020-10-28     sandra   simpson
# 2      licenciatura en administración       2021-01-24   jennifer      kidd
# 3      licenciatura en administración       2021-01-24   jennifer      kidd
# 4      licenciatura en administración       2021-01-24   jennifer      kidd
# ...                               ...              ...        ...       ...
# 12923                        actuario       2020-12-02     robert   johnson
# 12924                        actuario       2020-12-02     robert   johnson
# 12925                        actuario       2020-12-02     robert   johnson
# 12926                        actuario       2020-12-02     robert   johnson
# 12927                        actuario       2020-12-02     robert   johnson
#
#        gender  age     location_y                      email
# 0      female   85         grutly  spencermurphy@hotmail.com
# 1      female   85         grutly  spencermurphy@hotmail.com
# 2      female   46    agua blanca     alexisstokes@yahoo.com
# 3      female   46    agua blanca     alexisstokes@yahoo.com
# 4      female   46    agua blanca     alexisstokes@yahoo.com
# ...       ...  ...            ...                        ...
# 12923    male   35  blas durañona        melissa84@gmail.com
# 12924    male   35  blas durañona        melissa84@gmail.com
# 12925    male   35  blas durañona        melissa84@gmail.com
# 12926    male   35  blas durañona        melissa84@gmail.com
# 12927    male   35  blas durañona        melissa84@gmail.com
#
# [12928 rows x 17 columns]

# %%
df_2geonames_merge = df_geonames.merge(df_2, on='postal_code', how='right')

# %%
df_2geonames_merge
# Out:
#      country  postal_code       location_x        region type      lat  \
# 0         AR         8366       MIRA PAMPA     Rio Negro    R -39.0667
# 1         AR         8366      SANTA JULIA     Rio Negro    R -39.0667
# 2         AR         8366     LA TEODOLINA     Rio Negro    R -39.0667
# 3         AR         8366         CHELFORO     Rio Negro    R -39.0667
# 4         AR         8412      LA QUEBRADA     Rio Negro    R -41.3000
# ...      ...          ...              ...           ...  ...      ...
# 5172      AR         5442  AMBAS PUNTILLAS      San Juan    J -31.6542
# 5173      AR         5442          CAUCETE      San Juan    J -31.6542
# 5174      AR         7633            MAORI  Buenos Aires    B -38.3000
# 5175      AR         7633       TAMANGUEYU  Buenos Aires    B -38.2000
# 5176      AR         7633           PIERES  Buenos Aires    B -38.4000
#
#           lon  type_2                          university  \
# 0    -66.5333     3.0  universidad nacional de río cuarto
# 1    -66.5333     3.0  universidad nacional de río cuarto
# 2    -66.5333     3.0  universidad nacional de río cuarto
# 3    -66.5333     4.0  universidad nacional de río cuarto
# 4    -70.6667     3.0  universidad nacional de río cuarto
# ...       ...     ...                                 ...
# 5172 -68.2853     3.0  universidad nacional de río cuarto
# 5173 -68.2853     4.0  universidad nacional de río cuarto
# 5174 -58.7000     3.0  universidad nacional de río cuarto
# 5175 -58.7333     4.0  universidad nacional de río cuarto
# 5176 -58.6667     4.0  universidad nacional de río cuarto
#
#                                                  career inscription_date  \
# 0                             ingeniería en informática       2021-01-15
# 1                             ingeniería en informática       2021-01-15
# 2                             ingeniería en informática       2021-01-15
# 3                             ingeniería en informática       2021-01-15
# 4                                              farmacia       2020-10-02
# ...                                                 ...              ...
# 5172                licenciatura en terapia ocupacional       2020-12-28
# 5173                licenciatura en terapia ocupacional       2020-12-28
# 5174  licenciatura en ciencia y tecnología de alimentos       2021-01-24
# 5175  licenciatura en ciencia y tecnología de alimentos       2021-01-24
# 5176  licenciatura en ciencia y tecnología de alimentos       2021-01-24
#
#       first_name last_name  gender  age          location_y  \
# 0        michael     smith    male   27            chelforo
# 1        michael     smith    male   27            chelforo
# 2        michael     smith    male   27            chelforo
# 3        michael     smith    male   27            chelforo
# 4     jacqueline      gray  female   30  cañadon del corral
# ...          ...       ...     ...  ...                 ...
# 5172        mark   montoya    male   47     ambas puntillas
# 5173        mark   montoya    male   47     ambas puntillas
# 5174       erika       lee  female   34               maori
# 5175       erika       lee  female   34               maori
# 5176       erika       lee  female   34               maori
#
#                          email
# 0            laura64@yahoo.com
# 1            laura64@yahoo.com
# 2            laura64@yahoo.com
# 3            laura64@yahoo.com
# 4          uodonnell@yahoo.com
# ...                        ...
# 5172      aaronterry@gmail.com
# 5173      aaronterry@gmail.com
# 5174  bennettanthony@yahoo.com
# 5175  bennettanthony@yahoo.com
# 5176  bennettanthony@yahoo.com
#
# [5177 rows x 17 columns]

# %% [markdown]
# TOP 10 de carreras con más alumnos y con menos alumnos

# %%
df_aux = df_1.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_1.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.head(10), x='university', y='career', palette=colors_green, ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_green[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con más personas - {university1_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_aux = df_1.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_1.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.tail(10), x='university', y='career', palette=colors_red[10::-1], ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_red[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con menos personas - {university1_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_aux = df_2.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_2.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.head(10), x='university', y='career', palette=colors_green, ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_green[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con más personas - {university2_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_aux = df_2.groupby('career').count().reset_index().sort_values('university', ascending=False)
palette = sns.diverging_palette(120,12,s=55,l=70,n=33,center='dark')
plt.figure(figsize=(10, 8))
sns.barplot(data=df_aux, x='university', y='career', palette=palette)

plt.title(f'Personas por carrera - {university2_name}')
plt.xlabel('Cantidad de personas')
plt.ylabel('Carrera')

plt.show()

# %%
df_aux = df_2.groupby('career').count().reset_index().sort_values('university', ascending=False)
media_alumns_carrera = int(df_2.groupby('career').size().mean())

fig, ax = plt.subplots(figsize=(10, 8))

sns.barplot(data=df_aux.tail(10), x='university', y='career', palette=colors_red[10::-1], ax=ax)
ax.plot((media_alumns_carrera,media_alumns_carrera), (-0.5,9.5), color=colors_red[3],linestyle='dashed')
ax.set_title(f'Top 10 Carreras con menos personas - {university2_name}',{'fontsize':15})
ax.set_xlabel('Cantidad de personas', {'fontsize':11})
ax.set_ylabel('Carrera', {'fontsize':11})

fig.show()

# %%
df_1.columns
# Out:
# Index(['university', 'career', 'inscription_date', 'first_name', 'last_name',
#        'gender', 'age', 'postal_code', 'location', 'email'],
#       dtype='object')

# %%
df_1.shape
# Out:
# (1347, 10)

# %%
df_1.head()
# Out:
#              university                                             career  \
# 0  universidad de morón                              licenciatura en artes
# 1  universidad de morón                     licenciatura en administración
# 2  universidad de morón  licenciatura en ciencia y tecnología de alimentos
# 3  universidad de morón                              ciencias veterinarias
# 4  universidad de morón                                       arquitectura
#
#   inscription_date first_name last_name  gender  age  postal_code  \
# 0       2020-10-28     sandra   simpson  female   85         3083
# 1       2021-01-24   jennifer      kidd  female   46         5471
# 2       2020-11-09      robyn     walsh  female   54         4601
# 3       2020-12-02   samantha  thompson  female   27         5509
# 4       2020-10-08      james     lopez    male   26         5589
#
#             location                      email
# 0             grutly  spencermurphy@hotmail.com
# 1        agua blanca     alexisstokes@yahoo.com
# 2  corral de piedras         dawn84@hotmail.com
# 3             agrelo     meganolson@hotmail.com
# 4           chapanay         victor92@yahoo.com

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1347 entries, 0 to 1346
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   university        1347 non-null   object
#  1   career            1347 non-null   object
#  2   inscription_date  1347 non-null   object
#  3   first_name        1347 non-null   object
#  4   last_name         1347 non-null   object
#  5   gender            1347 non-null   object
#  6   age               1347 non-null   int64
#  7   postal_code       1347 non-null   int64
#  8   location          1347 non-null   object
#  9   email             1347 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 105.4+ KB

# %%
df_2.describe()
# Out:
#               age  postal_code
# count  571.000000   571.000000
# mean    35.178634  4943.455342
# std     10.238025  2265.354899
# min     18.000000  1607.000000
# 25%     26.000000  3032.000000
# 50%     35.000000  4722.000000
# 75%     44.000000  6616.000000
# max     53.000000  9420.000000

# %%
sns.violinplot(data=df_1,y='age', x='gender', palette=[colors_red[4], colors_green[4]])

# %%
sns.violinplot(data=df_2,y='age', x='gender', palette=[colors_red[4], colors_green[4]])

# %% [markdown]
# **Top 10 localidades por alumnos**

# %%
df_1.location.value_counts().head(10)
# Out:
# caraguatay           7
# alcorta              7
# adolfo alsina        6
# 9 de julio           5
# bella vista          5
# los polvorines       5
# general rodriguez    5
# agua blanca          5
# alto verde           5
# aguas calientes      5
# Name: location, dtype: int64

# %%
df_2.location.value_counts().head(10)
# Out:
# bosques             4
# campo caretto       3
# cholila             3
# alastuey            3
# berretta            3
# arroyo burgos       3
# cristolia           3
# alfredo demarchi    3
# 25 de mayo          3
# 3 de mayo           3
# Name: location, dtype: int64

# %% [markdown]
# **Distribucion de alumnos por edad y género**

# %%
sns.histplot(data=df_1,x='age', hue='gender', kde=True,fill=True,multiple='dodge', shrink=.5,stat='density', palette=[colors_red[4], colors_green[4]])

# %%
sns.histplot(data=df_2,x='age', hue='gender', kde=True,fill=True,multiple='dodge', shrink=.5,stat='density', palette=[colors_red[4], colors_green[4]])

# %%
df_1.inscription_date = pd.to_datetime(df_1.inscription_date)
df_2.inscription_date = pd.to_datetime(df_2.inscription_date)

# %% [markdown]
# Segregación por tipo de carrera

# %%
def clasificador(x):
    
    clasificador ={
    'exactas_nat':['agronomía','licenciatura en ciencias biológicas','licenciatura en ciencias ambientales','licenciatura en ciencias biológicas', 'licenciatura en ciencias geológicas', 
    'técnico para bioterios', 'ingeniería electrónica', 'ingeniería en informática','ingeniería mecánica','licenciatura en ciencias de la computación'],
    'ciencias_salud':['ciencias veterinarias','farmacia','licenciatura en kinesiología y fisiatría','licenciatura en producción de bioimagenes','medicina','licenciatura en gestión de agroalimentos', 'licenciatura en ciencia y tecnología de alimentos','bioquímica'],
    'diseño_art':['diseño industrial', 'diseño de imagen y sonido', 'licenciatura en artes', 'licenciatura en musicoterapia', ],
    'empresarial':['actuario', 'contador público','licenciatura en administración'],
    'sociales':['licenciatura en ciencias antropológicas','licenciatura en ciencias de la educación','licenciatura en psicología', 'licenciatura en relaciones del trabajo','licenciatura en sociología','licenciatura en terapia ocupacional']
}
    if x in clasificador['exactas_nat']:
        return "Exactas y Naturales"
    elif x in clasificador['diseño_art']:
        return "Artes y Diseño"
    elif x in clasificador['empresarial']:
        return "Ciencias Empresariales"
    elif x in clasificador['ciencias_salud']:
        return "Salud"
    else:
        return "Sociales"
df_1['tipo_career'] = df_1.career.apply(clasificador)

# %% [markdown]
# Proporción de alumnos por tipo de carrera y género

# %%
fig,ax = plt.subplots(figsize=(10,5))
g = sns.countplot(data=df_1,
                    x='tipo_career',
                    hue='gender',
                    palette=[colors_red[5],
                    colors_green[5]],
                    ax=ax)

g.set_title(f'Tipo de Carrera por Género - {university1_name}',{'fontsize':15})
g.set_ylabel('Cantidad de alumnos',{'fontsize':12,'color':colors_dark[3]})
g.set_xlabel('Tipo de carrera',{'fontsize':12,'color':colors_dark[3]})
g.set_xticklabels(labels=g.get_xticklabels())
ax.legend(labels=['Mujer','Varon'])

# %%
fig,ax=plt.subplots(figsize=(15,4))
df_aux = df_1geonames_merge.pivot_table(
    index=['region'],
    columns='gender',
    values=['first_name'],
    aggfunc={'region':'count'}
)
df_aux.plot(kind='bar',color=(colors_red[5],colors_green[5]),ax=ax)
ax.set_title(f'Alumnos por región y por género - {university1_name}',{'fontsize':15})
ax.set_ylabel('Cantidad de alumnos',{'color':colors_dark[3]})
ax.tick_params(axis='x', colors=colors_dark[3])
ax.set_xlabel('')
ax.legend(labels=['Mujer','Varon'])
fig.show()

# %%
def clasificador(x):
    
    clasificador ={
    'exactas_nat':['agronomía','licenciatura en ciencias biológicas','licenciatura en ciencias ambientales','licenciatura en ciencias biológicas', 'licenciatura en ciencias geológicas', 
    'técnico para bioterios', 'ingeniería electrónica', 'ingeniería en informática','ingeniería mecánica','licenciatura en ciencias de la computación'],
    'ciencias_salud':['ciencias veterinarias','farmacia','licenciatura en kinesiología y fisiatría','licenciatura en producción de bioimagenes','medicina','licenciatura en gestión de agroalimentos', 'licenciatura en ciencia y tecnología de alimentos','bioquímica'],
    'diseño_art':['diseño industrial', 'diseño de imagen y sonido', 'licenciatura en artes', 'licenciatura en musicoterapia', ],
    'empresarial':['actuario', 'contador público','licenciatura en administración'],
    'sociales':['licenciatura en ciencias antropológicas','licenciatura en ciencias de la educación','licenciatura en psicología', 'licenciatura en relaciones del trabajo','licenciatura en sociología','licenciatura en terapia ocupacional']
}
    if x in clasificador['exactas_nat']:
        return "Exactas y Naturales"
    elif x in clasificador['diseño_art']:
        return "Artes y Diseño"
    elif x in clasificador['empresarial']:
        return "Ciencias Empresariales"
    elif x in clasificador['ciencias_salud']:
        return "Salud"
    else:
        return "Sociales"
df_2['tipo_career'] = df_2.career.apply(clasificador)

# %%
fig,ax = plt.subplots(figsize=(10,5))
g = sns.countplot(data=df_2,
                    x='tipo_career',
                    hue='gender',
                    palette=[colors_red[5],
                    colors_green[5]],
                    ax=ax)

g.set_title(f'Tipo de Carrera por Género - {university2_name}',{'fontsize':15})
g.set_ylabel('Cantidad de alumnos',{'fontsize':12,'color':colors_dark[3]})
g.set_xlabel('Tipo de carrera',{'fontsize':12,'color':colors_dark[3]})
g.set_xticklabels(labels=g.get_xticklabels())
ax.legend(labels=['Mujer','Varon'])

# %%
fig,ax=plt.subplots(figsize=(15,4))
df_aux = df_2geonames_merge.pivot_table(
    index=['region'],
    columns='gender',
    values=['first_name'],
    aggfunc={'region':'count'}
)
df_aux.plot(kind='bar',color=(colors_red[5],colors_green[5]),ax=ax)
ax.set_title(f'Alumnos por región y por género - {university2_name}',{'fontsize':15})
ax.set_ylabel('Cantidad de alumnos',{'color':colors_dark[3]})
ax.tick_params(axis='x', colors=colors_dark[3])
ax.set_xlabel('')
ax.legend(labels=['Mujer','Varon'])
fig.show()

# %%
career = 'ingeniería en informática'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()

# %%
career = 'bioquímica'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()

# %%
career = 'medicina'

df_aux = df_1.query(f'career == "{career}"').gender.value_counts()

colors = sns.color_palette('pastel')
labels = ['Varón', 'Mujer']
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'   Cantidad de personas por genero en {career.capitalize()} - {university1_name}    ')
plt.show()

df_aux = df_2.query(f'career == "{career}"').gender.value_counts()
plt.pie(df_aux, colors = (colors_green[5],colors_red[5]), labels=labels, autopct = '%0.0f%%')

plt.title(f'Cantidad de personas por genero en {career.capitalize()} - {university2_name}')
plt.show()
